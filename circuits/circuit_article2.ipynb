# %%
from qiskit import *
from numpy import pi
from qiskit.extensions import Initialize

qreg_q = QuantumRegister(3, 'q')

initial_state = [0, 1]

circuit = QuantumCircuit(qreg_q)

circuit.initialize(initial_state, 0)

circuit.csx(qreg_q[1], qreg_q[2])
circuit.csx(qreg_q[0], qreg_q[2])

circuit.measure

circuit.draw(output = 'mpl')

#circuit.append(Initialize(initial_state), [0])

#initial_state = [1 / 2 ** 0.5, 1 / 2 ** 0.5]
#circuit.append(Initialize(initial_state), [1])

#initial_state = [1 / 2 ** 0.5, 1 / 2 ** 0.5]
#circuit.append(Initialize(initial_state), [2])

#circuit.measure(qreg_q[0], creg_c[0])
#circuit.measure(qreg_q[1], creg_c[1])

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend = simulator).result()
statevector = result.get_statevector()
print(statevector)
# Out:
# Statevector([0. +0.j , 0.5+0.5j, 0. +0.j , 0. +0.j , 0. +0.j , 0.5-0.5j,
#              0. +0.j , 0. +0.j ],
#             dims=(2, 2, 2))

# %%
from qiskit.tools.visualization import plot_bloch_multivector

plot_bloch_multivector(statevector)
